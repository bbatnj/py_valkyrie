# %%
# %run D:\valkyrie_shared\python\apps\run_notebook_import.py
# Out:
# <style>.container { width:100% !important; }</style>
# D:/valkyrie_shared/sim_dir

# %%
from valkyrie.components.trade_summary import SimViewer

# %%
gsv = GroupSimViewer('trading_config_test3')

# %%
gsv.view()
# Out:
#                              sharpe  win_ratio        mean      median  \
# trading_config_test3_0001  8.467655   0.782258  420.538627  425.421948
# trading_config_test3_0002  6.964831   0.733871  358.069272  371.125950
# trading_config_test3_0003  9.047343   0.806452  451.046939  420.197296
# trading_config_test3_0004  7.597975   0.750000  386.638252  419.609059
# trading_config_test3_0005  9.561384   0.838710  480.409789  456.247186
# trading_config_test3_0006  8.353631   0.774194  446.110387  435.933230
# trading_config_test3_0007  9.369846   0.774194  478.029155  468.938995
# trading_config_test3_0008  8.462516   0.806452  468.622486  429.022585
# trading_config_test3_0009  9.114117   0.798387  446.993770  425.850064
# trading_config_test3_0010  8.176436   0.790323  444.600640  426.594693
# trading_config_test3_0011  8.805297   0.774194  433.687555  424.013701
# trading_config_test3_0012  8.755664   0.798387  461.412736  459.991528
# ...

# %%
SimViewer('trading_config_test3/trading_config_test3_0007').view()
# Out:
#                   edge          pnl      pos_pnl     fee_pnl     dvd_rcvd  \
# sharpe       27.493776     9.330249     4.469506  -33.643383     4.635147
# win_ratio     1.000000     0.782258     0.653226    0.000000     0.145161
# mean       1830.603992   330.543724   197.637778  -56.758153    70.337097
# median     1447.288919   341.364119   191.222109  -48.767500     0.000000
# max        5191.427374  3482.633185  2322.377626  -18.874000  1858.240000
# min         432.973742 -1463.533164 -2881.113432 -126.957000     0.000000
# std        1056.964206   562.387859   701.957308   26.781128   240.891368
#
#               dvd_paid    total_pnl           $pos       $volume  \
# sharpe       -3.584582     9.369846            NaN           NaN
# win_ratio     0.000000     0.774194            NaN           NaN
# mean        -63.731290   478.029155   38649.372017  8.490077e+05
# median        0.000000   468.938995   31557.902424  7.302882e+05
# ...
