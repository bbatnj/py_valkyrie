# %%
import gc
import os

import numpy as np
import pandas as pd

from sklearn.linear_model import LinearRegression as LR
from valkyrie.components.trade_summary import Summary

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# %matplotlib notebook
pd.set_option('display.max_rows', 800)

from valkyrie.quants.feature_analyzer import FeatureMgr
from valkyrie.securities import stocks_good_dvd
from valkyrie.components.trade_summary import SimViewer
# Out:
# <style>.container { width:100% !important; }</style>

# %%
SimViewer('eve_features3_2x0_quoter_cooldown_600').view()
# Out:
# <img src="data:image/png;base64,..." width="1500">
#                   edge          pnl      pos_pnl     fee_pnl     dvd_rcvd  \
# sharpe       33.657646     8.122254     4.537988  -40.373905     3.827427
# win_ratio     1.000000     0.758065     0.612903    0.000000     0.129032
# mean       1577.582592   228.615223   145.685348  -50.928000    58.316694
# median     1429.778040   220.904397   120.043513  -45.934500     0.000000
# max        4570.401533  2231.239928  1444.015026  -19.440000  2027.310000
# min         440.602321 -1092.942422 -2048.562236 -127.285000     0.000000
# std         744.061169   446.816152   509.627481   20.024244   241.872392
#
#               dvd_paid    total_pnl           $pos       $volume  \
# sharpe       -3.634176     8.458613            NaN           NaN
# win_ratio     0.000000     0.758065            NaN           NaN
# mean        -54.738226   326.951039   37717.539780  9.639829e+05
# ...

# %%
SimViewer('eve_features3_2x0').view()
# Out:
# <img src="data:image/png;base64,..." width="1500">
#                   edge          pnl      pos_pnl     fee_pnl     dvd_rcvd  \
# sharpe       32.149846     8.609725     4.788610  -38.972237     3.903606
# win_ratio     1.000000     0.733871     0.669355    0.000000     0.129032
# mean       1912.658593   267.003937   157.697730  -58.327734    49.954435
# median     1706.133898   286.663480   168.324648  -52.571000     0.000000
# max        5651.167169  2516.648853  1513.377408  -19.918000  1648.120000
# min         473.638220 -1285.692020 -2844.007999 -145.041000     0.000000
# std         944.406187   492.298646   522.776756   23.758556   203.146016
#
#               dvd_paid    total_pnl           $pos       $volume  \
# sharpe       -3.791963     9.039228            NaN           NaN
# win_ratio     0.000000     0.758065            NaN           NaN
# mean        -56.950081   359.378289   38795.470440  1.190851e+06
# ...

# %%
SimViewer('eve_features3_2x0_quoter_cooldown_300').view()
# Out:
# <img src="data:image/png;base64,..." width="1500">
#                   edge          pnl      pos_pnl     fee_pnl     dvd_rcvd  \
# sharpe       32.540114     7.418755     4.373563  -39.958074     3.813879
# win_ratio     1.000000     0.677419     0.669355    0.000000     0.129032
# mean       1744.690778   222.717506   135.758402  -54.783266    53.237016
# median     1513.713911   219.279284   141.372425  -48.114500     0.000000
# max        4891.000834  2230.609706  1548.450851  -19.099000  1954.150000
# min         488.469240 -1248.849557 -2350.218403 -125.021000     0.000000
# std         851.137371   476.566567   492.755628   21.764247   221.588451
#
#               dvd_paid    total_pnl           $pos       $volume  \
# sharpe       -3.527912     7.936300            NaN           NaN
# win_ratio     0.000000     0.709677            NaN           NaN
# mean        -53.179839   303.749819   40018.231604  1.082891e+06
# ...

# %%
SimViewer('eve_features3_2x0_quoter_cooldown_300').view()
# Out:
# <img src="data:image/png;base64,..." width="1500">
#                   edge          pnl      pos_pnl     fee_pnl     dvd_rcvd  \
# sharpe       32.540114     7.418755     4.373563  -39.958074     3.813879
# win_ratio     1.000000     0.677419     0.669355    0.000000     0.129032
# mean       1744.690778   222.717506   135.758402  -54.783266    53.237016
# median     1513.713911   219.279284   141.372425  -48.114500     0.000000
# max        4891.000834  2230.609706  1548.450851  -19.099000  1954.150000
# min         488.469240 -1248.849557 -2350.218403 -125.021000     0.000000
# std         851.137371   476.566567   492.755628   21.764247   221.588451
#
#               dvd_paid    total_pnl           $pos       $volume  \
# sharpe       -3.527912     7.936300            NaN           NaN
# win_ratio     0.000000     0.709677            NaN           NaN
# mean        -53.179839   303.749819   40018.231604  1.082891e+06
# ...
